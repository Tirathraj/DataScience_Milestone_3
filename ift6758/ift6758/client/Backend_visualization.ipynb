# %%
pwd
# Out:
# 'C:\\Users\\rambu\\Python Scripts\\Milestone_3\\docker-project-template\\ift6758\\ift6758\\client'

# %%
from game_client import get_df_by_game

# %%
df = get_df_by_game(2025020001)
df.shape
# Out:
# Fetched 2025020001
# 2025020001 is NOT LIVE
# (82, 42)

# %%
df.head(1)
# Out:
#       game_id    season  game_type game_outcome game_state  period_number  \
# 0  2025020001  20252026          2          REG        OFF              1
#
#   period_type time_in_period  strength    event_type  ... away_score  \
# 0         REG          01:16       NaN  shot-on-goal  ...          2
#
#                 venue  venue_location  is_goal empty_net  x_mean_home  \
# 0  Amerant Bank Arena         Sunrise        0         0        -61.0
#
#   x_distance distance_net  angle_deg angle_rad
# 0         31    38.013156  35.362462  0.617191
#
# [1 rows x 42 columns]

# %%
df = get_df_by_game(2025020377)
df.shape
# Out:
# Fetched 2025020377
# 2025020377 is LIVE
# (32, 42)

# %%
live_df = get_df_by_game(2025020377)
live_df.shape
# Out:
# Fetched 2025020377
# 2025020377 is LIVE
# (35, 42)

# %%
df.tail(3)
# Out:
#        game_id    season  game_type  game_outcome game_state  period_number  \
# 29  2025020377  20252026          2           NaN       LIVE              1
# 30  2025020377  20252026          2           NaN       LIVE              1
# 31  2025020377  20252026          2           NaN       LIVE              2
#
#    period_type time_in_period  strength    event_type  ... away_score  \
# 29         REG          19:35       NaN   missed-shot  ...          2
# 30         REG          19:50       NaN  shot-on-goal  ...          2
# 31         REG          00:34       NaN          goal  ...          2
#
#                    venue  venue_location  is_goal empty_net  x_mean_home  \
# 29  Little Caesars Arena         Detroit        0         0   -67.266667
# 30  Little Caesars Arena         Detroit        0         0   -67.266667
# 31  Little Caesars Arena         Detroit        1         0          NaN
#
#    x_distance distance_net  angle_deg angle_rad
# 29          9    24.698178  68.629378  1.197809
# 30         22    22.803509  15.255119  0.266252
# 31         15    15.132746   7.594643  0.132552
#
# [3 rows x 42 columns]

# %%
live_df.tail(5)
# Out:
#        game_id    season  game_type  game_outcome game_state  period_number  \
# 30  2025020377  20252026          2           NaN       LIVE              1
# 31  2025020377  20252026          2           NaN       LIVE              2
# 32  2025020377  20252026          2           NaN       LIVE              2
# 33  2025020377  20252026          2           NaN       LIVE              2
# 34  2025020377  20252026          2           NaN       LIVE              2
#
#    period_type time_in_period  strength    event_type  ... away_score  \
# 30         REG          19:50       NaN  shot-on-goal  ...          2
# 31         REG          00:34       NaN          goal  ...          2
# 32         REG          00:59       NaN   missed-shot  ...          2
# 33         REG          01:01       NaN  shot-on-goal  ...          2
# 34         REG          02:26       NaN  shot-on-goal  ...          2
#
#                    venue  venue_location  is_goal empty_net  x_mean_home  \
# 30  Little Caesars Arena         Detroit        0         0   -67.266667
# 31  Little Caesars Arena         Detroit        1         0    61.333333
# 32  Little Caesars Arena         Detroit        0         0    61.333333
# 33  Little Caesars Arena         Detroit        0         0    61.333333
# 34  Little Caesars Arena         Detroit        0         0    61.333333
#
#    x_distance distance_net  angle_deg angle_rad
# 30         22    22.803509  15.255119  0.266252
# 31         15    15.132746   7.594643  0.132552
# 32         24    32.557641  42.510447  0.741947
# 33          3     3.605551  33.690068  0.588003
# 34         56    56.320511   6.115504  0.106736
#
# [5 rows x 42 columns]
